# %%
class book:
    category="fiction"
book1=book()
print(book1.category)
# Out:
# fiction

# %%
class laptop:
    def __init__(self,brand,ram_gb):
        self.brand =brand
        self.ram_gb=ram_gb
laptop1= laptop("dell", 16)
print(laptop1.brand,laptop1.ram_gb)
# Out:
# dell 16
